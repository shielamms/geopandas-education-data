# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import requests
import string

from bs4 import BeautifulSoup
from shapely.geometry import Point, Polygon
from urllib.parse import urljoin

# %% [markdown]
# ## Base Map: UK Counties

# %%
# Source: https://www.ukpostcode.net/shapefile-of-uk-administrative-counties-wiki-16.html
counties = gpd.read_file('datasets/UK/UK_counties/Map_UK.shp', crs='epsg:32630')

# %%
base = counties.plot(figsize=(9,9), color='whitesmoke', edgecolor='gainsboro')
base.axis('off')
# Out:
# (-185523.71342924781, 871502.387163905, 5468290.709205763, 6808384.907171282)

# %%
counties.crs
# Out:
# <Derived Projected CRS: EPSG:32630>
# Name: WGS 84 / UTM zone 30N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 6°W and 0°W, northern hemisphere between equator and 84°N, onshore and offshore. Algeria. Burkina Faso. Côte' Ivoire (Ivory Coast). Faroe Islands - offshore. France. Ghana. Gibraltar. Ireland - offshore Irish Sea. Mali. Mauritania. Morocco. Spain. United Kingdom (UK).
# - bounds: (-6.0, 0.0, 0.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 30N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
counties.loc[counties['NAME_1'] == 'England']
# Out:
#      ID_0  ISO          NAME_0  ID_1   NAME_1   ID_2  \
# 0      80  GBR  United Kingdom  1030  England  13936
# 1      80  GBR  United Kingdom  1030  England  13937
# 2      80  GBR  United Kingdom  1030  England  13938
# 3      80  GBR  United Kingdom  1030  England  13939
# 4      80  GBR  United Kingdom  1030  England  13940
# ..    ...  ...             ...   ...      ...    ...
# 107    80  GBR  United Kingdom  1030  England  14043
# 108    80  GBR  United Kingdom  1030  England  14044
# 109    80  GBR  United Kingdom  1030  England  14045
# 110    80  GBR  United Kingdom  1030  England  14046
# 111    80  GBR  United Kingdom  1030  England  14047
#
#                            NAME_2 VARNAME_2 NL_NAME_2 HASC_2  CC_2  \
# 0            Barking and Dagenham      None      None  GB.BA  None
# 1    Bath and North East Somerset      None      None  GB.BN  None
# 2                    Bedfordshire      None      None  GB.BD  None
# 3                       Berkshire      None      None  GB.BK  None
# 4                          Bexley      None      None  GB.XB  None
# ..                            ...       ...       ...    ...   ...
# 107                West Yorkshire      None      None  GB.WY  None
# 108                   Westminster      None      None  GB.WE  None
# 109                     Wiltshire      None      None  GB.WL  None
# 110                Worcestershire      None      None  GB.WC  None
# 111                          York      None      None  GB.YK  None
#
#                        TYPE_2                 ENGTYPE_2  \
# 0              London Borough            London Borough
# 1           Unitary Authority         Unitary Authority
# 2       Administrative County     Administrative County
# 3                      County                    County
# 4              London Borough            London Borough
# ..                        ...                       ...
# 107       Metropolitan County       Metropolitan County
# 108     London Borough (city)     London Borough (city)
# 109     Administrative County     Administrative County
# 110     Administrative County     Administrative County
# 111  Unitary Authority (city)  Unitary Authority (city)
#
#                  VALIDFR_2 VALIDTO_2  \
# 0                     None   Present
# 1                 19960401   Present
# 2                    ~1989   Present
# 3    Between 1900 and 1974   Present
# 4                     None   Present
# ..                     ...       ...
# 107               19740401   Present
# 108                   None   Present
# 109  Between 1900 and 1974   Present
# 110  Between 1900 and 1974   Present
# 111               19960401   Present
#
#                                           REMARKS_2  Shape_Leng  Shape_Area  \
# 0                                              None    0.368272    0.004932
# 1                                              None    1.146163    0.039882
# 2                                              None    2.158565    0.147815
# 3    non-metropolitan county with no county council    2.825418    0.158283
# 4                                              None    0.452624    0.008851
# ..                                              ...         ...         ...
# 107                                            None    2.711164    0.276423
# 108                                            None    0.281644    0.002742
# 109                                            None    3.652696    0.409599
# 110                                            None    3.085356    0.234855
# 111                                            None    0.844667    0.041281
#
#                                               geometry
# 0    POLYGON ((719316.591 5716960.249, 719365.616 5...
# 1    POLYGON ((550019.968 5696813.117, 550299.618 5...
# 2    POLYGON ((679380.073 5794077.687, 679674.028 5...
# 3    POLYGON ((658761.890 5714402.155, 659890.480 5...
# 4    POLYGON ((721667.295 5708401.122, 721818.676 5...
# ..                                                 ...
# 107  POLYGON ((573672.433 5979954.150, 574059.478 5...
# 108  POLYGON ((696535.612 5712807.900, 697032.209 5...
# 109  POLYGON ((584568.563 5723977.927, 585888.651 5...
# 110  POLYGON ((552987.902 5809768.935, 556366.848 5...
# 111  POLYGON ((631993.119 5982583.609, 634201.211 5...
#
# [112 rows x 19 columns]

# %%
england = counties.loc[counties['NAME_1'] == 'England']
base = england.plot(figsize=(10,10), color='whitesmoke', edgecolor='gainsboro')
london = (england.loc[counties['TYPE_2']
                      .isin([
                             'London Borough',
                             'London Borough (city)',
                             'London Borough (royal)'])])
london.plot(ax=base, column='NAME_2', cmap='Paired', alpha=0.4, zorder=1)

base.axis('off')

plt.annotate(text='London',
             xy=(7.15e5, 5.71e6),
             xytext=(8.6e5, 5.72e6),
             horizontalalignment='left',
             verticalalignment='top',
             fontsize=11,
             arrowprops={'arrowstyle': '->', 'color': 'red'},
             color='black')
# Out:
# Text(860000.0, 5720000.0, 'London')

# %% [markdown]
# ## UK Postcodes to Coordinates Mapping

# %%
# Source (with inner postcodes):
# https://www.ordnancesurvey.co.uk/business-government/products/code-point-open?_ga=2.240870595.1507098495.1663492775-1223826065.1663492775&_gl=1*1df549f*_ga*MTIyMzgyNjA2NS4xNjYzNDkyNzc1*_ga_59ZBN7DVBG*MTY2MzQ5Mjc3NS4xLjEuMTY2MzQ5NTA3NC40MS4wLjA.

# Source (with outer postcodes only):
# https://www.ukpostcode.net/download-uk-postcodes-with-latitude-and-longitude-wiki-4.html
uk_postcodes = pd.read_csv('datasets/UK/UK_outer_postcodes.csv')

# %%
uk_postcodes
# Out:
#       AB10  392900   804900  57.13  -2.11    Aberdeen       Aberdeen .1
# 0     AB11  394500   805300  57.13  -2.09    Aberdeen         Aberdeen
# 1     AB12  393300   801100  57.10  -2.11    Aberdeen         Aberdeen
# 2     AB13  385600   801900  57.10  -2.23   Milltimber   Aberdeenshire
# 3     AB14  383600   801100  57.10  -2.27  Peterculter   Aberdeenshire
# 4     AB15  390000   805300  57.13  -2.16    Aberdeen         Aberdeen
# ...    ...     ...      ...    ...    ...          ...              ...
# 2815   YO7  442400   481100  54.22  -1.35      Thirsk   North Yorkshire
# 2816   YO8  462100   432100  53.78  -1.05       Selby   North Yorkshire
# 2817   ZE1  446200  1141100  60.15  -1.16    Shetland         Shetland
# 2818   ZE2  442800  1160900  60.33  -1.22    Shetland         Shetland
# 2819   ZE3  439000  1111100  59.88  -1.30    Shetland         Shetland
#
# [2820 rows x 7 columns]

# %%
# The current column header is supposedly a data record
headers = ['outer_post_code', 'x', 'y', 'lat', 'long', 'locality', 'county']
record = uk_postcodes.columns.to_list()

# Clean up the "Aberdeen .1"
record[-1] = record[-1][:-3]
record = pd.DataFrame(dict(zip(headers, record)), index=[0])

uk_postcodes.columns = headers
uk_postcodes = pd.concat([uk_postcodes, record], axis=0).reset_index(drop=True)

# %%
uk_postcodes
# Out:
#      outer_post_code       x        y    lat   long     locality  \
# 0               AB11  394500   805300  57.13  -2.09    Aberdeen
# 1               AB12  393300   801100   57.1  -2.11    Aberdeen
# 2               AB13  385600   801900   57.1  -2.23   Milltimber
# 3               AB14  383600   801100   57.1  -2.27  Peterculter
# 4               AB15  390000   805300  57.13  -2.16    Aberdeen
# ...              ...     ...      ...    ...    ...          ...
# 2816             YO8  462100   432100  53.78  -1.05       Selby
# 2817             ZE1  446200  1141100  60.15  -1.16    Shetland
# 2818             ZE2  442800  1160900  60.33  -1.22    Shetland
# 2819             ZE3  439000  1111100  59.88   -1.3    Shetland
# 2820            AB10  392900   804900  57.13  -2.11    Aberdeen
#
#                county
# 0           Aberdeen
# 1           Aberdeen
# 2      Aberdeenshire
# 3      Aberdeenshire
# 4           Aberdeen
# ...               ...
# 2816  North Yorkshire
# 2817        Shetland
# 2818        Shetland
# 2819        Shetland
# 2820         Aberdeen
#
# [2821 rows x 7 columns]

# %%
# EPSG 27700 is the preferred coordinate system for UK locations.
# The fields to use are x and y, which are a standard from UK Ordnance Survey
geometry = [Point(xy) for xy in zip(uk_postcodes['x'].astype(int), uk_postcodes['y'].astype(int))]
crs = {'init': 'epsg:27700'}
postcodes_gdf = gpd.GeoDataFrame(uk_postcodes, crs=crs, geometry=geometry)
# Out:
# /Users/shielasandoval/Geospatial/venv/lib/python3.8/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
postcodes_gdf.plot(figsize=(9,9))
# Out:
# <AxesSubplot: >

# %%
postcodes_gdf = postcodes_gdf.to_crs('epsg:32630')
postcodes_gdf.crs
# Out:
# <Derived Projected CRS: EPSG:32630>
# Name: WGS 84 / UTM zone 30N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 6°W and 0°W, northern hemisphere between equator and 84°N, onshore and offshore. Algeria. Burkina Faso. Côte' Ivoire (Ivory Coast). Faroe Islands - offshore. France. Ghana. Gibraltar. Ireland - offshore Irish Sea. Mali. Mauritania. Morocco. Spain. United Kingdom (UK).
# - bounds: (-6.0, 0.0, 0.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 30N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
base = counties.plot(figsize=(12,12), color='whitesmoke', edgecolor='gainsboro')
base.axis('off')

postcodes_gdf.plot(ax=base, column='county', cmap='Pastel1', zorder=1)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## UK Universities from UCAS

# %%
# Scrape from https://www.ucas.com/explore/unis?letter=<parameter>

# THE CODE IN THIS CELL WILL BE MOVED TO A SEPARATE HELPER SCRIPT

# start_url = 'https://www.ucas.com/explore/unis'
# params = {'letter': None}
# all_letters = string.ascii_lowercase
# universities = []

# for letter in all_letters:
#     params['letter'] = letter
#     print(f'Getting all universities from letter {letter}')
#     response = requests.get(start_url, params=params)
#     results_soup = BeautifulSoup(response.content)
    
#     # get each university name and location
#     unis = results_soup.select('.link-container__link')
#     print(f'  Got {len(unis)}')
#     for uni in unis:
#         uni_name = uni.get('title')
#         uni_url = urljoin(start_url, uni.get('href'))
#         response = requests.get(uni_url)
#         uni_content_soup = BeautifulSoup(response.content)
#         location = uni_content_soup.select_one('.content-block__section.content-block__section--grow p').text
#         postcode = location.split(',')[-1]
    
#         uni_data = {'name': uni_name, 'url': uni_url, 'address': location, 'postcode': postcode}
#         universities.append(uni_data)
# Out:
# Getting all universities from letter a
#   Got 14
# Getting all universities from letter b
#   Got 41
# Getting all universities from letter c
#   Got 28
# Getting all universities from letter d
#   Got 9
# Getting all universities from letter e
#   Got 15
# Getting all universities from letter f
#   Got 5
# Getting all universities from letter g
#   Got 12
# Getting all universities from letter h
#   Got 22
# Getting all universities from letter i
#   Got 4
# Getting all universities from letter j
#   Got 0
# Getting all universities from letter k
#   Got 7
# Getting all universities from letter l
#   Got 31
# Getting all universities from letter m
#   Got 9
# Getting all universities from letter n
#   Got 19
# Getting all universities from letter o
#   Got 4
# Getting all universities from letter p
#   Got 11
# Getting all universities from letter q
#   Got 3
# Getting all universities from letter r
#   Got 19
# Getting all universities from letter s
#   Got 38
# Getting all universities from letter t
#   Got 8
# Getting all universities from letter u
#   Got 16
# Getting all universities from letter v
#   Got 0
# Getting all universities from letter w
#   Got 21
# Getting all universities from letter x
#   Got 0
# Getting all universities from letter y
#   Got 4
# Getting all universities from letter z
#   Got 0

# %%
# pd.DataFrame(universities).to_csv('datasets/UK/ucas_universities_2022.csv', index=False)

# %%
ucas_unis = pd.read_csv('datasets/UK/ucas_universities_2022.csv')
len(ucas_unis)
# Out:
# 340

# %%
ucas_unis['address'].apply(lambda x: x.split(',')[-2] if len(x.split()) > 2 else x.split(',')[-1])
# Out:
# 0              Aberdeen
# 1               Tayside
# 2            Ceredigion
# 3                Surrey
# 4           Oxfordshire
#              ...
# 335               Essex
# 336            Somerset
# 337     North Yorkshire
# 338     North Yorkshire
# 339                York
# Name: address, Length: 340, dtype: object

# %% [markdown]
# ## Top UK universities

# %%
# Source: https://www.thecompleteuniversityguide.co.uk/league-tables/rankings
# Original download is .numbers, converted to .csv, with some manually deleted headers
rankings = pd.read_csv('datasets/UK/university_ranks.csv')
len(rankings)
# Out:
# 130

# %%
rankings.head()
# Out:
#    Rank                                        Institution  Entry Standards  \
# 0     1                               University of Oxford              200
# 1     2                            University of Cambridge              205
# 2     3  London School of Economics and Political Scien...              177
# 3     4                           University of St Andrews              208
# 4     5                            Imperial College London              194
#
#    Student Satisfaction  Research Quality  Research Intensity  \
# 0                   NaN              3.34                0.87
# 1                   NaN              3.33                0.95
# 2                  3.98              3.35                0.85
# 3                  4.30              3.13                0.82
# 4                  3.99              3.36                0.92
#
#    Graduate prospects outcomes  Graduate prospects on track  \
# 0                         90.4                         84.7
# 1                         90.0                         86.0
# 2                         90.6                         83.3
# 3                         79.9                         79.6
# 4                         95.1                         86.7
#
#    Student-Staff Ratio  Academic Services Spend  Facilities Spend  \
# 0                 10.1                     2842               599
# 1                 11.4                     2718              1043
# 2                 12.4                     2051               853
# 3                 11.1                     2650               746
# 4                 11.1                     2982               755
#
#    Degree Completion  Overall Score
# 0               99.1           1000
# 1               99.1            989
# 2               96.5            963
# 3               95.7            947
# 4               97.5            895

# %%
top_unis = rankings.merge(ucas_unis, how='inner', right_on='name', left_on='Institution')
top_unis
# Out:
#      Rank                                        Institution  Entry Standards  \
# 0       1                               University of Oxford              200
# 1       2                            University of Cambridge              205
# 2       3  London School of Economics and Political Scien...              177
# 3       4                           University of St Andrews              208
# 4       5                            Imperial College London              194
# ..    ...                                                ...              ...
# 124   126                              University of Suffolk              110
# 125   127                          University of East London               97
# 126   128                        Glyndwr University, Wrexham              102
# 127   129                     Ravensbourne University London              113
# 128   130                         University of Bedfordshire              103
#
#      Student Satisfaction  Research Quality  Research Intensity  \
# 0                     NaN              3.34                0.87
# 1                     NaN              3.33                0.95
# 2                    3.98              3.35                0.85
# 3                    4.30              3.13                0.82
# 4                    3.99              3.36                0.92
# ..                    ...               ...                 ...
# 124                  3.96               NaN                 NaN
# 125                  4.00              2.71                0.23
# 126                  4.14              2.15                0.16
# 127                  3.80               NaN                 NaN
# 128                  3.93              2.52                0.27
#
#      Graduate prospects outcomes  Graduate prospects on track  \
# 0                           90.4                         84.7
# 1                           90.0                         86.0
# 2                           90.6                         83.3
# 3                           79.9                         79.6
# 4                           95.1                         86.7
# ..                           ...                          ...
# 124                         74.4                         80.9
# 125                         56.5                         69.6
# 126                         62.9                         68.6
# 127                         70.0                         77.5
# 128                         66.2                         73.1
#
#      Student-Staff Ratio  Academic Services Spend  Facilities Spend  \
# 0                   10.1                     2842               599
# 1                   11.4                     2718              1043
# 2                   12.4                     2051               853
# 3                   11.1                     2650               746
# 4                   11.1                     2982               755
# ..                   ...                      ...               ...
# 124                 16.5                     1961               478
# 125                 21.9                     1105               756
# 126                 21.9                     1334               559
# 127                 22.6                     1163               322
# 128                 23.5                     1750               673
#
#      Degree Completion  Overall Score  \
# 0                 99.1           1000
# 1                 99.1            989
# 2                 96.5            963
# 3                 95.7            947
# 4                 97.5            895
# ..                 ...            ...
# 124               65.0            395
# 125               76.5            374
# 126               73.3            364
# 127               79.7            333
# 128               53.1            304
#
#                                                   name  \
# 0                                 University of Oxford
# 1                              University of Cambridge
# 2    London School of Economics and Political Scien...
# 3                             University of St Andrews
# 4                              Imperial College London
# ..                                                 ...
# 124                              University of Suffolk
# 125                          University of East London
# 126                        Glyndwr University, Wrexham
# 127                     Ravensbourne University London
# 128                         University of Bedfordshire
#
#                                                    url  \
# 0    https://www.ucas.com/explore/unis/351374e0/uni...
# 1    https://www.ucas.com/explore/unis/badc3603/uni...
# 2    https://www.ucas.com/explore/unis/25fe3db7/lon...
# 3    https://www.ucas.com/explore/unis/81fe3292/uni...
# 4    https://www.ucas.com/explore/unis/52087408/imp...
# ..                                                 ...
# 124  https://www.ucas.com/explore/unis/cf271b96/uni...
# 125  https://www.ucas.com/explore/unis/6d89f913/uni...
# 126  https://www.ucas.com/explore/unis/fdb6a3ab/gly...
# 127  https://www.ucas.com/explore/unis/6f003a01/rav...
# 128  https://www.ucas.com/explore/unis/3261960f/uni...
#
#                                                address   postcode
# 0    Undergraduate Admissions Office, Wellington Sq...    OX1 2JD
# 1    Cambridge Admissions Office\r\nStudent Service...    CB2 3PT
# 2           Houghton Street,, London, London, WC2A 2AE   WC2A 2AE
# 3    St Katharine's West, 16 The Scores, 16 The Sco...   KY16 9AX
# 4                          Kensington, London, SW7 2AZ    SW7 2AZ
# ..                                                 ...        ...
# 124  Waterfront Building, Neptune Quay, Neptune Qua...    IP4 1QJ
# 125            University Way, London, London, E16 2RD    E16 2RD
# 126  Mold Road, Mold Road, Wrexham, Denbighshire, L...   LL11 2AW
# 127           6 Penrose Way,, London, London, SE10 0EW   SE10 0EW
# 128    University Square, Luton, Bedfordshire, LU1 3JU    LU1 3JU
#
# [129 rows x 17 columns]

# %% [markdown]
# One university was not mathed with the rankings data - find what that is and insert into the top_unis

# %%
mask = rankings['Institution'].isin(ucas_unis['name'])

# %%
rankings[~mask]
# Out:
#     Rank              Institution  Entry Standards  Student Satisfaction  \
# 11    12  University of Edinburgh              186                  3.86
#
#     Research Quality  Research Intensity  Graduate prospects outcomes  \
# 11              3.18                0.83                         79.6
#
#     Graduate prospects on track  Student-Staff Ratio  Academic Services Spend  \
# 11                         78.8                 11.7                     1407
#
#     Facilities Spend  Degree Completion  Overall Score
# 11               808               93.3            801

# %%
ucas_unis.loc[ucas_unis['name'].str.contains('Edinburgh')]
# Out:
#                                      name  \
# 99            Edinburgh Napier University
# 100           The University of Edinburgh
# 231  Queen Margaret University, Edinburgh
#
#                                                    url  \
# 99   https://www.ucas.com/explore/unis/dc3ccbfc/edi...
# 100  https://www.ucas.com/explore/unis/114bb2e7/the...
# 231  https://www.ucas.com/explore/unis/403c3afa/que...
#
#                                                address   postcode
# 99   Merchiston Campus\r\n10 Colinton Road, Edinbur...   EH10 5DT
# 100      Old College, South Bridge, Edinburgh, EH8 9YL    EH8 9YL
# 231  Queen Margaret Drive, Edinburgh, Musselburgh, ...   EH21 6UU

# %%
df1 = ucas_unis.loc[ucas_unis['name'] == 'The University of Edinburgh'].reset_index(drop=True)
df2 = rankings.loc[rankings['Institution'] == 'University of Edinburgh'].reset_index(drop=True)
edinburgh = pd.concat([df2, df1], axis=1)
top_unis = pd.concat([top_unis, edinburgh], axis=0).reset_index(drop=True).sort_values(by='Rank')

# %%
len(top_unis)
# Out:
# 130

# %%
top_unis.head()
# Out:
#    Rank                                        Institution  Entry Standards  \
# 0     1                               University of Oxford              200
# 1     2                            University of Cambridge              205
# 2     3  London School of Economics and Political Scien...              177
# 3     4                           University of St Andrews              208
# 4     5                            Imperial College London              194
#
#    Student Satisfaction  Research Quality  Research Intensity  \
# 0                   NaN              3.34                0.87
# 1                   NaN              3.33                0.95
# 2                  3.98              3.35                0.85
# 3                  4.30              3.13                0.82
# 4                  3.99              3.36                0.92
#
#    Graduate prospects outcomes  Graduate prospects on track  \
# 0                         90.4                         84.7
# 1                         90.0                         86.0
# 2                         90.6                         83.3
# 3                         79.9                         79.6
# 4                         95.1                         86.7
#
#    Student-Staff Ratio  Academic Services Spend  Facilities Spend  \
# 0                 10.1                     2842               599
# 1                 11.4                     2718              1043
# 2                 12.4                     2051               853
# 3                 11.1                     2650               746
# 4                 11.1                     2982               755
#
#    Degree Completion  Overall Score  \
# 0               99.1           1000
# 1               99.1            989
# 2               96.5            963
# 3               95.7            947
# 4               97.5            895
#
#                                                 name  \
# 0                               University of Oxford
# 1                            University of Cambridge
# 2  London School of Economics and Political Scien...
# 3                           University of St Andrews
# 4                            Imperial College London
#
#                                                  url  \
# 0  https://www.ucas.com/explore/unis/351374e0/uni...
# 1  https://www.ucas.com/explore/unis/badc3603/uni...
# 2  https://www.ucas.com/explore/unis/25fe3db7/lon...
# 3  https://www.ucas.com/explore/unis/81fe3292/uni...
# 4  https://www.ucas.com/explore/unis/52087408/imp...
#
#                                              address   postcode
# 0  Undergraduate Admissions Office, Wellington Sq...    OX1 2JD
# 1  Cambridge Admissions Office\r\nStudent Service...    CB2 3PT
# 2         Houghton Street,, London, London, WC2A 2AE   WC2A 2AE
# 3  St Katharine's West, 16 The Scores, 16 The Sco...   KY16 9AX
# 4                        Kensington, London, SW7 2AZ    SW7 2AZ

# %% [markdown]
# ### Get outer postcode to join with postcodes and counties data

# %%
top_unis['outer_post_code'] = (
    top_unis['postcode'].str.strip().str.split(' ').apply(lambda x: x[0])
)

# %%
top_unis.head()
# Out:
#    Rank                                        Institution  Entry Standards  \
# 0     1                               University of Oxford              200
# 1     2                            University of Cambridge              205
# 2     3  London School of Economics and Political Scien...              177
# 3     4                           University of St Andrews              208
# 4     5                            Imperial College London              194
#
#    Student Satisfaction  Research Quality  Research Intensity  \
# 0                   NaN              3.34                0.87
# 1                   NaN              3.33                0.95
# 2                  3.98              3.35                0.85
# 3                  4.30              3.13                0.82
# 4                  3.99              3.36                0.92
#
#    Graduate prospects outcomes  Graduate prospects on track  \
# 0                         90.4                         84.7
# 1                         90.0                         86.0
# 2                         90.6                         83.3
# 3                         79.9                         79.6
# 4                         95.1                         86.7
#
#    Student-Staff Ratio  Academic Services Spend  Facilities Spend  \
# 0                 10.1                     2842               599
# 1                 11.4                     2718              1043
# 2                 12.4                     2051               853
# 3                 11.1                     2650               746
# 4                 11.1                     2982               755
#
#    Degree Completion  Overall Score  \
# 0               99.1           1000
# 1               99.1            989
# 2               96.5            963
# 3               95.7            947
# 4               97.5            895
#
#                                                 name  \
# 0                               University of Oxford
# 1                            University of Cambridge
# 2  London School of Economics and Political Scien...
# 3                           University of St Andrews
# 4                            Imperial College London
#
#                                                  url  \
# 0  https://www.ucas.com/explore/unis/351374e0/uni...
# 1  https://www.ucas.com/explore/unis/badc3603/uni...
# 2  https://www.ucas.com/explore/unis/25fe3db7/lon...
# 3  https://www.ucas.com/explore/unis/81fe3292/uni...
# 4  https://www.ucas.com/explore/unis/52087408/imp...
#
#                                              address   postcode  \
# 0  Undergraduate Admissions Office, Wellington Sq...    OX1 2JD
# 1  Cambridge Admissions Office\r\nStudent Service...    CB2 3PT
# 2         Houghton Street,, London, London, WC2A 2AE   WC2A 2AE
# 3  St Katharine's West, 16 The Scores, 16 The Sco...   KY16 9AX
# 4                        Kensington, London, SW7 2AZ    SW7 2AZ
#
#   outer_post_code
# 0             OX1
# 1             CB2
# 2            WC2A
# 3            KY16
# 4             SW7

# %%
top_uni_locs = postcodes_gdf.merge(top_unis, how='inner', on='outer_post_code')
len(top_uni_locs)
# Out:
# 129

# %%
# one top uni that did not match postcodes
mask = top_unis.loc[~top_unis['outer_post_code'].isin(postcodes_gdf['outer_post_code'])]
mask
# Out:
#     Rank             Institution  Entry Standards  Student Satisfaction  \
# 36    38  University of Aberdeen              182                  4.06
#
#     Research Quality  Research Intensity  Graduate prospects outcomes  \
# 36              2.97                0.73                         74.8
#
#     Graduate prospects on track  Student-Staff Ratio  Academic Services Spend  \
# 36                         77.2                 15.7                     1744
#
#     Facilities Spend  Degree Completion  Overall Score  \
# 36               701               88.5            686
#
#                       name                                                url  \
# 36  University of Aberdeen  https://www.ucas.com/explore/unis/3a023828/uni...
#
#                                address   postcode outer_post_code
# 36  King's College, Aberdeen, AB24 3FX   AB24 3FX            AB24

# %%
# provisionally edit the outer_post_code of University of Aberdeen to match current postcodes data
top_unis.loc[top_unis['Institution'] == 'University of Aberdeen', 'outer_post_code'] = 'AB25'

# %%
# try merging top unis and postcodes again..
top_uni_locs = postcodes_gdf.merge(top_unis, how='inner', on='outer_post_code')
len(top_uni_locs)
# Out:
# 130

# %%
top_uni_locs.head(2)
# Out:
#   outer_post_code       x       y    lat  long   locality          county  \
# 0            AB25  393200  806900  57.15 -2.11  Aberdeen        Aberdeen
# 1            AL10  522200  208300  51.76 -0.23   Hatfield  Hertfordshire
#
#                          geometry  Rank                  Institution  ...  \
# 0  POINT (553598.848 6334757.088)    38       University of Aberdeen  ...
# 1  POINT (691103.814 5737980.591)    80  University of Hertfordshire  ...
#
#    Graduate prospects on track  Student-Staff Ratio  Academic Services Spend  \
# 0                         77.2                 15.7                     1744
# 1                         74.3                 15.6                     1638
#
#    Facilities Spend  Degree Completion  Overall Score  \
# 0               701               88.5            686
# 1              1122               82.0            545
#
#                           name  \
# 0       University of Aberdeen
# 1  University of Hertfordshire
#
#                                                  url  \
# 0  https://www.ucas.com/explore/unis/3a023828/uni...
# 1  https://www.ucas.com/explore/unis/e2cc6194/uni...
#
#                                              address   postcode
# 0                 King's College, Aberdeen, AB24 3FX   AB24 3FX
# 1  University Admissions Service, College Lane, C...   AL10 9AB
#
# [2 rows x 25 columns]

# %%
# clean the counties
top_uni_locs['county'] = top_uni_locs['county'].str.strip()

# %%
top_uni_locs = top_uni_locs.sort_values(by='Rank')

# %% [markdown]
# ## Map of top UK universities

# %%
top_uni_locs[:10]
# Out:
#     outer_post_code       x       y    lat  long       locality  \
# 85              OX1  451100  205400  51.74 -1.25        Oxford
# 20              CB2  545900  253800  52.16  0.13     Cambridge
# 123            WC2A  530800  181400  51.51 -0.11        London
# 55             KY16  349400  716900  56.34 -2.81  Saint Andrews
# 110             SW7  526700  179100  51.49 -0.17        London
# 33              DH1  427900  543000  54.78 -1.56         Durham
# 63             LE11  452900  319400  52.76 -1.21   Loughborough
# 120            WC1E  529600  181900  51.52 -0.13        London
# 29              CV4  429600  277900  52.39 -1.56       Coventry
# 6               BA2  373800  162400  51.36 -2.37           Bath
#
#              county                        geometry  Rank  \
# 85      Oxfordshire  POINT (620037.782 5734105.007)     1
# 20   Cambridgeshire  POINT (714181.392 5783814.040)     2
# 123          London  POINT (700073.661 5711194.374)     3
# 55             Fife  POINT (511118.570 6244129.714)     4
# 110          London  POINT (696004.478 5708837.943)     5
# 33    County Durham  POINT (592114.345 6071377.662)     6
# 63   Leicestershire  POINT (620263.611 5848132.073)     7
# 120          London  POINT (698866.632 5711678.038)     8
# 29    West Midlands  POINT (597539.188 5806308.966)     9
# 6          Somerset  POINT (543329.084 5690049.840)    10
#
#                                            Institution  ...  \
# 85                                University of Oxford  ...
# 20                             University of Cambridge  ...
# 123  London School of Economics and Political Scien...  ...
# 55                            University of St Andrews  ...
# 110                            Imperial College London  ...
# 33                                   Durham University  ...
# 63                             Loughborough University  ...
# 120                    UCL (University College London)  ...
# 29                               University of Warwick  ...
# 6                                   University of Bath  ...
#
#      Graduate prospects on track  Student-Staff Ratio  \
# 85                          84.7                 10.1
# 20                          86.0                 11.4
# 123                         83.3                 12.4
# 55                          79.6                 11.1
# 110                         86.7                 11.1
# 33                          82.3                 13.5
# 63                          83.0                 13.5
# 120                         83.4                 10.1
# 29                          81.5                 12.8
# 6                           85.6                 15.1
#
#      Academic Services Spend  Facilities Spend  Degree Completion  \
# 85                      2842               599               99.1
# 20                      2718              1043               99.1
# 123                     2051               853               96.5
# 55                      2650               746               95.7
# 110                     2982               755               97.5
# 33                      2174              1085               96.8
# 63                      1853              1375               93.4
# 120                     2338               325               94.3
# 29                      1643               795               95.1
# 6                       1913               703               96.0
#
#      Overall Score                                               name  \
# 85            1000                               University of Oxford
# 20             989                            University of Cambridge
# 123            963  London School of Economics and Political Scien...
# 55             947                           University of St Andrews
# 110            895                            Imperial College London
# 33             889                                  Durham University
# 63             868                            Loughborough University
# 120            854                    UCL (University College London)
# 29             842                              University of Warwick
# 6              840                                 University of Bath
#
#                                                    url  \
# 85   https://www.ucas.com/explore/unis/351374e0/uni...
# 20   https://www.ucas.com/explore/unis/badc3603/uni...
# 123  https://www.ucas.com/explore/unis/25fe3db7/lon...
# 55   https://www.ucas.com/explore/unis/81fe3292/uni...
# 110  https://www.ucas.com/explore/unis/52087408/imp...
# 33   https://www.ucas.com/explore/unis/6e455568/dur...
# 63   https://www.ucas.com/explore/unis/b935bbb7/lou...
# 120  https://www.ucas.com/explore/unis/bd0c70d8/ucl...
# 29   https://www.ucas.com/explore/unis/e59d51a1/uni...
# 6    https://www.ucas.com/explore/unis/295cc6a3/uni...
#
#                                                address   postcode
# 85   Undergraduate Admissions Office, Wellington Sq...    OX1 2JD
# 20   Cambridge Admissions Office\r\nStudent Service...    CB2 3PT
# 123         Houghton Street,, London, London, WC2A 2AE   WC2A 2AE
# 55   St Katharine's West, 16 The Scores, 16 The Sco...   KY16 9AX
# 110                        Kensington, London, SW7 2AZ    SW7 2AZ
# 33   The Palatine Centre, Stockton Road, South Road...    DH1 3LE
# 63   Epinal Way, Loughborough, Leicestershire, LE11...   LE11 3TU
# 120             Gower Street, London, London, WC1E 6BT   WC1E 6BT
# 29   University of Warwick, Coventry, West Midlands...    CV4 7AL
# 6    University of BathClaverton Down, Claverton Do...    BA2 7AY
#
# [10 rows x 25 columns]

# %%
top10 = top_uni_locs[:10]
top_counties = (top_uni_locs
                .groupby('county')
                .agg({'geometry': lambda x: x,
                      'lat': lambda x: x,
                      'long': lambda x: x,
                      'locality': lambda x: list(x),
                      'name': lambda x: list(x)})
                .reset_index())
top_counties['count'] = (
    top_counties['geometry'].apply(lambda x: len(x) if isinstance(x, gpd.array.GeometryArray) else 1))
top_counties['geometry'] = (
    top_counties['geometry'].apply(lambda x: x[0] if isinstance(x, gpd.array.GeometryArray) else x))
top_counties['lat'] = (
    top_counties['lat'].apply(lambda x: x[0] if isinstance(x, np.ndarray) else x))
top_counties['long'] = (
    top_counties['long'].apply(lambda x: x[0] if isinstance(x, np.ndarray) else x))
top_counties['locality'] = (
    top_counties['locality'].apply(lambda x: x[0].strip() if isinstance(x, list) else x.strip()))
top_counties['name'] = (
    top_counties['name'].apply(lambda x: ',\n'.join(y for y in x) if isinstance(x, list) else x.strip()))
# top_counties = gpd.GeoDataFrame(top_counties, geometry=top_counties['geometry'])

# %%
# merge top uni counties with counties to minimuse mismatches
matched_by_name = top_counties.merge(counties, how='inner', left_on='county', right_on='NAME_2')
unmatched_counties = top_counties.loc[~top_counties['county'].isin(matched_by_name['county'])]

matched_by_alt_name = unmatched_counties.merge(counties, how='inner', left_on='county', right_on='VARNAME_2')
matched_top_counties = pd.concat([matched_by_name, matched_by_alt_name], axis=0).reset_index(drop=True)

matched_top_counties = gpd.GeoDataFrame(matched_top_counties, geometry=matched_top_counties['geometry_y'])
matched_top_counties
# Out:
#               county                                    geometry_x    lat  \
# 0           Aberdeen   POINT (553598.847716016 6334757.0878634835)  57.15
# 1              Angus  POINT (501325.39148499625 6257387.813581432)  56.46
# 2       Bedfordshire   POINT (677230.3701700165 5750294.066540756)  51.87
# 3          Berkshire   POINT (643699.9539630723 5700721.069649863)  51.43
# 4    Buckinghamshire   POINT (656016.4307577533 5721694.905267646)  51.62
# 5     Cambridgeshire   POINT (714181.3920908907 5783814.039706429)  52.16
# 6         Ceredigion   POINT (428364.9400934233 5804068.845491355)  52.38
# 7           Cheshire  POINT (506100.48827969574 5894746.039051152)  53.20
# 8           Cornwall  POINT (350841.5241655942 5557358.2608969975)  50.14
# 19  1.08            Canterbury
# 20 -2.79             Lancaster
# 21 -1.21          Loughborough
# 22 -0.59               Lincoln
# 23 -0.11                London
# 24 -3.28                Currie
# 25  1.26               Norwich
# 26 -1.05                  York
# 27 -0.88           Northampton
# 28 -1.61   Newcastle Upon Tyne
# 29 -1.17            Nottingham
# 30 -1.25                Oxford
# 31 -4.41               Paisley
# 32 -2.38               Newport
# 33 -2.37                  Bath
# 34 -1.51             Sheffield
# 35 -2.23  Newcastle-under-Lyme
# 36 -3.94              Stirling
# 37  1.18               Ipswich
# 38 -0.55                 Egham
# 39 -3.99               Swansea
# 40 -1.56              Coventry
# 41 -1.54                 Leeds
# 42 -2.24             Worcester
# 43 -1.56                Durham
#
#                                                  name  count  ID_0  ISO  \
# 0   University of Aberdeen,\nRobert Gordon University      2    80  GBR
# 1           University of Dundee,\nAbertay University      2    80  GBR
# 2                          University of Bedfordshire      1    80  GBR
# 3                               University of Reading      1    80  GBR
# 4   Buckinghamshire New University,\nUniversity of...      2    80  GBR
# 5   University of Cambridge,\nAnglia Ruskin Univer...      2    80  GBR
# 6                              Aberystwyth University      1    80  GBR
# 7                               University of Chester      1    80  GBR
# 8                                 Falmouth University      1    80  GBR
# 9                         Glyndwr University, Wrexham      1    80  GBR
# 10                                University of Derby      1    80  GBR
# 11  University of Exeter,\nUniversity of Plymouth,...      3    80  GBR
# 12  Arts University Bournemouth,\nBournemouth Univ...      2    80  GBR
# 13  The University of Edinburgh,\nEdinburgh Napier...      2    80  GBR
# 14                                University of Essex      1    80  GBR
# 15                           University of St Andrews      1    80  GBR
# 16  University of Bristol,\nBristol, University of...      4    80  GBR
# 17  University of Southampton,\nUniversity of Port...      4    80  GBR
# 18                        University of Hertfordshire      1    80  GBR
# 19  University of Kent,\nCanterbury Christ Church ...      2    80  GBR
# 20  Lancaster University,\nUniversity of Mancheste...     10    80  GBR
# 21  Loughborough University,\nUniversity of Leices...      3    80  GBR
# 22  University of Lincoln,\nBishop Grosseteste Uni...      2    80  GBR
# 23  London School of Economics and Political Scien...     18    80  GBR
# 24  Heriot-Watt University,\nQueen Margaret Univer...      2    80  GBR
# 25  University of East Anglia UEA,\nNorwich Univer...      2    80  GBR
# 26  University of York,\nTeesside University, Midd...      3    80  GBR
# 27                          University of Northampton      1    80  GBR
# 28  Newcastle University,\nNorthumbria University,...      2    80  GBR
# 29  University of Nottingham,\nNottingham Trent Un...      2    80  GBR
# 30   University of Oxford,\nOxford Brookes University      2    80  GBR
# 31                 University of the West of Scotland      1    80  GBR
# 32                            Harper Adams University      1    80  GBR
# 33           University of Bath,\nBath Spa University      2    80  GBR
# 34  University of Sheffield,\nSheffield Hallam Uni...      2    80  GBR
# 35  Keele University,\nStaffordshire University,\n...      3    80  GBR
# 36                             University of Stirling      1    80  GBR
# 37                              University of Suffolk      1    80  GBR
# 38  Royal Holloway, University of London,\nUnivers...      4    80  GBR
# 39  Swansea University,\nUniversity of Wales Trini...      2    80  GBR
# 40  University of Warwick,\nUniversity of Birmingh...      6    80  GBR
# 18     Administrative County  Between 1900 and 1974   Present
# 19     Administrative County  Between 1900 and 1974   Present
# 20     Administrative County  Between 1900 and 1974   Present
# 21     Administrative County  Between 1900 and 1974   Present
# 22     Administrative County                  ~1989   Present
# 23     London Borough (city)                   None   Present
# 24          Unitary District                   1929   Present
# 25     Administrative County  Between 1900 and 1974   Present
# 26     Administrative County               19740401   Present
# 27     Administrative County  Between 1900 and 1974   Present
# 28     Administrative County  Between 1900 and 1974   Present
# 29     Administrative County  Between 1900 and 1974   Present
# 30     Administrative County  Between 1900 and 1974   Present
# 31          Unitary District                   1929   Present
# 32     Administrative County  Between 1900 and 1974   Present
# 33     Administrative County  Between 1900 and 1974   Present
# 34       Metropolitan County               19740401   Present
# 35     Administrative County  Between 1900 and 1974   Present
# 36          Unitary District                   1929   Present
# 37     Administrative County                  ~1989   Present
# 38     Administrative County  Between 1900 and 1974   Present
# 39  Unitary Authority (wales               19960401   Present
# 40       Metropolitan County               19740401   Present
# 41       Metropolitan County               19740401   Present
# 42     Administrative County  Between 1900 and 1974   Present
# 43     Administrative County  Between 1900 and 1974   Present
#
#                                          REMARKS_2 Shape_Leng Shape_Area  \
# 0                                             None   1.009378   0.032908
# 1                                             None   3.266633   0.309782
# 2                                             None   2.158565   0.147815
# 3   non-metropolitan county with no county council   2.825418   0.158283
# 4                                             None   3.259887   0.204493
# 5                                             None   3.897993   0.403477
# 6                                             None   3.448064   0.247170
# 7                                             None   3.391066   0.291374
# 8                                             None  11.989156   0.455993
# 9                                             None   2.019631   0.111664
# 10                                            None   3.987888   0.346483
# 11                                            None   9.777576   0.842028
# 12                                            None   5.340477   0.332904
# 13                                            None   1.239247   0.043295
# 14                                            None   6.819509   0.444600
# 15                                            None   4.359427   0.188834
# 16                                            None   3.856851   0.352750
# 17                                            None   5.911131   0.471148
# 18                                            None   2.877341   0.212896
# 19                                            None   5.933326   0.455536
# 20                                            None   4.610209   0.398787
# 21                                            None   3.284745   0.272967
# 22                                            None   5.837272   0.801532
# 23                                            None   0.084161   0.000329
# 24                                            None   1.347597   0.049392
# 25                                            None   5.199644   0.726440
# 26                                            None   7.913089   1.097025
# 27                                            None   3.388638   0.306563
# 28                                            None   5.808264   0.714211
# 29                                            None   3.143569   0.278290
# 30                                            None   3.519565   0.341336
# 31                                            None   1.103554   0.039070
# 32                                            None   4.832909   0.423416
# 33                                            None   4.856435   0.439670
# 34                                            None   2.573024   0.222283
# 35                                            None   4.231415   0.347675
# 36                                            None   3.498503   0.332081
# 37                                            None   5.734590   0.492656
# 38                                            None   2.556893   0.216244
# 39                                            None   1.767350   0.049196
# 40                                            None   2.127797   0.116415
# 41                                            None   2.711164   0.276423
# 42                                            None   3.085356   0.234855
# 43                                            None   3.020754   0.310822
#
#                                            geometry_y  \
# 0   POLYGON ((548894.824 6343496.931, 549827.112 6...
# 1   POLYGON ((510283.864 6314460.933, 511723.756 6...
# 2   POLYGON ((679380.073 5794077.687, 679674.028 5...
# 3   POLYGON ((658761.890 5714402.155, 659890.480 5...
# 23 -0.11                London
# 24 -3.28                Currie
# 25  1.26               Norwich
# 26 -1.05                  York
# 27 -0.88           Northampton
# 28 -1.61   Newcastle Upon Tyne
# 29 -1.17            Nottingham
# 30 -1.25                Oxford
# 31 -4.41               Paisley
# 32 -2.38               Newport
# 33 -2.37                  Bath
# 34 -1.51             Sheffield
# 35 -2.23  Newcastle-under-Lyme
# 36 -3.94              Stirling
# 37  1.18               Ipswich
# 38 -0.55                 Egham
# 39 -3.99               Swansea
# 40 -1.56              Coventry
# 41 -1.54                 Leeds
# 42 -2.24             Worcester
# 43 -1.56                Durham
#
#                                                  name  count  ID_0  ISO  \
# 0   University of Aberdeen,\nRobert Gordon University      2    80  GBR
# 1           University of Dundee,\nAbertay University      2    80  GBR
# 2                          University of Bedfordshire      1    80  GBR
# 3                               University of Reading      1    80  GBR
# 4   Buckinghamshire New University,\nUniversity of...      2    80  GBR
# 5   University of Cambridge,\nAnglia Ruskin Univer...      2    80  GBR
# 6                              Aberystwyth University      1    80  GBR
# 7                               University of Chester      1    80  GBR
# 8                                 Falmouth University      1    80  GBR
# 9                         Glyndwr University, Wrexham      1    80  GBR
# 10                                University of Derby      1    80  GBR
# 11  University of Exeter,\nUniversity of Plymouth,...      3    80  GBR
# 12  Arts University Bournemouth,\nBournemouth Univ...      2    80  GBR
# 13  The University of Edinburgh,\nEdinburgh Napier...      2    80  GBR
# 14                                University of Essex      1    80  GBR
# 15                           University of St Andrews      1    80  GBR
# 16  University of Bristol,\nBristol, University of...      4    80  GBR
# 17  University of Southampton,\nUniversity of Port...      4    80  GBR
# 18                        University of Hertfordshire      1    80  GBR
# 19  University of Kent,\nCanterbury Christ Church ...      2    80  GBR
# 20  Lancaster University,\nUniversity of Mancheste...     10    80  GBR
# 21  Loughborough University,\nUniversity of Leices...      3    80  GBR
# 22  University of Lincoln,\nBishop Grosseteste Uni...      2    80  GBR
# 23  London School of Economics and Political Scien...     18    80  GBR
# 24  Heriot-Watt University,\nQueen Margaret Univer...      2    80  GBR
# 25  University of East Anglia UEA,\nNorwich Univer...      2    80  GBR
# 26  University of York,\nTeesside University, Midd...      3    80  GBR
# 27                          University of Northampton      1    80  GBR
# 28  Newcastle University,\nNorthumbria University,...      2    80  GBR
# 29  University of Nottingham,\nNottingham Trent Un...      2    80  GBR
# 30   University of Oxford,\nOxford Brookes University      2    80  GBR
# 31                 University of the West of Scotland      1    80  GBR
# 32                            Harper Adams University      1    80  GBR
# 33           University of Bath,\nBath Spa University      2    80  GBR
# 34  University of Sheffield,\nSheffield Hallam Uni...      2    80  GBR
# 35  Keele University,\nStaffordshire University,\n...      3    80  GBR
# 36                             University of Stirling      1    80  GBR
# 37                              University of Suffolk      1    80  GBR
# 38  Royal Holloway, University of London,\nUnivers...      4    80  GBR
# 39  Swansea University,\nUniversity of Wales Trini...      2    80  GBR
# 40  University of Warwick,\nUniversity of Birmingh...      6    80  GBR
# 41  University of Leeds,\nUniversity of Huddersfie...      5    80  GBR
# 42                            University of Worcester      1    80  GBR
# 20     Administrative County  Between 1900 and 1974   Present
# 21     Administrative County  Between 1900 and 1974   Present
# 22     Administrative County                  ~1989   Present
# 23     London Borough (city)                   None   Present
# 24          Unitary District                   1929   Present
# 25     Administrative County  Between 1900 and 1974   Present
# 26     Administrative County               19740401   Present
# 27     Administrative County  Between 1900 and 1974   Present
# 28     Administrative County  Between 1900 and 1974   Present
# 29     Administrative County  Between 1900 and 1974   Present
# 30     Administrative County  Between 1900 and 1974   Present
# 31          Unitary District                   1929   Present
# 32     Administrative County  Between 1900 and 1974   Present
# 33     Administrative County  Between 1900 and 1974   Present
# 34       Metropolitan County               19740401   Present
# 35     Administrative County  Between 1900 and 1974   Present
# 36          Unitary District                   1929   Present
# 37     Administrative County                  ~1989   Present
# 38     Administrative County  Between 1900 and 1974   Present
# 39  Unitary Authority (wales               19960401   Present
# 40       Metropolitan County               19740401   Present
# 41       Metropolitan County               19740401   Present
# 42     Administrative County  Between 1900 and 1974   Present
# 43     Administrative County  Between 1900 and 1974   Present
#
#                                          REMARKS_2 Shape_Leng Shape_Area  \
# 0                                             None   1.009378   0.032908
# 1                                             None   3.266633   0.309782
# 2                                             None   2.158565   0.147815
# 3   non-metropolitan county with no county council   2.825418   0.158283
# 4                                             None   3.259887   0.204493
# 5                                             None   3.897993   0.403477
# 6                                             None   3.448064   0.247170
# 7                                             None   3.391066   0.291374
# 8                                             None  11.989156   0.455993
# 9                                             None   2.019631   0.111664
# 10                                            None   3.987888   0.346483
# 11                                            None   9.777576   0.842028
# 12                                            None   5.340477   0.332904
# 13                                            None   1.239247   0.043295
# 14                                            None   6.819509   0.444600
# 15                                            None   4.359427   0.188834
# 16                                            None   3.856851   0.352750
# 17                                            None   5.911131   0.471148
# 18                                            None   2.877341   0.212896
# 19                                            None   5.933326   0.455536
# 20                                            None   4.610209   0.398787
# 21                                            None   3.284745   0.272967
# 22                                            None   5.837272   0.801532
# 23                                            None   0.084161   0.000329
# 24                                            None   1.347597   0.049392
# 25                                            None   5.199644   0.726440
# 26                                            None   7.913089   1.097025
# 27                                            None   3.388638   0.306563
# 28                                            None   5.808264   0.714211
# 29                                            None   3.143569   0.278290
# 30                                            None   3.519565   0.341336
# 31                                            None   1.103554   0.039070
# 32                                            None   4.832909   0.423416
# 33                                            None   4.856435   0.439670
# 34                                            None   2.573024   0.222283
# 35                                            None   4.231415   0.347675
# 36                                            None   3.498503   0.332081
# 37                                            None   5.734590   0.492656
# 38                                            None   2.556893   0.216244
# 39                                            None   1.767350   0.049196
# 40                                            None   2.127797   0.116415
# 41                                            None   2.711164   0.276423
# 42                                            None   3.085356   0.234855
# 43                                            None   3.020754   0.310822
#
#                                            geometry_y  \
# 0   POLYGON ((548894.824 6343496.931, 549827.112 6...
# 1   POLYGON ((510283.864 6314460.933, 511723.756 6...
# 2   POLYGON ((679380.073 5794077.687, 679674.028 5...
# 3   POLYGON ((658761.890 5714402.155, 659890.480 5...
# 4   POLYGON ((641147.796 5771041.153, 644006.239 5...
# 5   POLYGON ((716566.133 5838210.639, 715449.582 5...
# 10  POLYGON ((592620.201 5907193.178, 594127.433 5...
# 11  MULTIPOLYGON (((435937.040 5570319.822, 435936...
# 12  MULTIPOLYGON (((541473.022 5603856.233, 541473...
# 13  MULTIPOLYGON (((482032.736 6205668.613, 482032...
# 14  MULTIPOLYGON (((750145.531 5715351.171, 750147...
# 15  MULTIPOLYGON (((481426.128 6209628.644, 481425...
# 16  POLYGON ((587989.897 5771270.203, 588656.974 5...
# 17  MULTIPOLYGON (((604010.016 5622273.088, 604010...
# 18  POLYGON ((697778.700 5767618.940, 698350.846 5...
# 19  MULTIPOLYGON (((766183.567 5696662.307, 766185...
# 20  POLYGON ((535646.856 6007828.061, 531878.110 6...
# 21  POLYGON ((656640.364 5853325.550, 657585.747 5...
# 22  MULTIPOLYGON (((718504.158 5859915.053, 718505...
# 23  POLYGON ((703147.579 5711276.576, 703224.014 5...
# 24  POLYGON ((495125.211 6200285.778, 495125.176 6...
# 25  POLYGON ((747639.007 5877328.112, 747640.599 5...
# 26  POLYGON ((643790.912 6047810.682, 643791.901 6...
# 27  POLYGON ((671200.831 5827219.237, 672109.387 5...
# 28  MULTIPOLYGON (((592800.393 6133246.636, 592803...
# 29  POLYGON ((645469.869 5920822.964, 645868.152 5...
# 30  POLYGON ((620751.682 5773193.810, 620329.096 5...
# 31  POLYGON ((398397.238 6199900.997, 398396.505 6...
# 32  POLYGON ((542321.617 5867636.049, 541973.796 5...
# 33  MULTIPOLYGON (((498778.212 5675819.328, 498778...
# 34  POLYGON ((636039.283 5947322.632, 641498.869 5...
# 35  POLYGON ((576414.954 5892501.987, 578611.430 5...
# 36  POLYGON ((418643.700 6266223.834, 420544.498 6...
# 37  MULTIPOLYGON (((797421.954 5775903.903, 797423...
# 38  POLYGON ((677904.887 5701647.757, 678533.751 5...
# 39  MULTIPOLYGON (((408221.113 5713627.919, 408220...
# 40  POLYGON ((574715.430 5830292.402, 575828.245 5...
# 41  POLYGON ((573672.433 5979954.150, 574059.478 5...
# 42  POLYGON ((552987.902 5809768.935, 556366.848 5...
# 43  POLYGON ((579163.526 6084195.674, 583302.318 6...
#
# [44 rows x 27 columns]

# %%
base = counties.plot(figsize=(15,12), color='whitesmoke', edgecolor='gainsboro')
base.axis('off')

matched_top_counties.plot(ax=base, column='count', cmap='YlOrBr', legend=True, zorder=1)

matched_top_counties['coords'] = (
    matched_top_counties['geometry_x'].apply(lambda x: x.representative_point().coords[:])
)
matched_top_counties['coords'] = [coords[0] for coords in matched_top_counties['coords']]

for idx, row in matched_top_counties.iterrows():
    x = row['coords'][0]
    y = row['coords'][1]
    plt.annotate(text=f"{row['county'] + '('+str(row['count'])+')' if row['count'] > 4 else ''}",
#                  text=f"{row['county']} ({row['name'] if row['count'] <= 2 else str(row['count']) + ' universities'})",
                 xy=(x,y-1e2),
#                  xytext=(x+4.2e5, y),
                 xytext=(x, y+3e4),
                 horizontalalignment='left',
                 verticalalignment='top',
                 fontsize=9,
#                  arrowprops={'arrowstyle': '<-', 'color': 'dimgrey', 'linewidth': 0.4},
                 color='black')
